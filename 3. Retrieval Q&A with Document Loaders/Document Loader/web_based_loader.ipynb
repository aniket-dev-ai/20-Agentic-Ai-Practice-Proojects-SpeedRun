# %%
from langchain_community.document_loaders import WebBaseLoader
# Out:
# C:\Users\Aniket\AppData\Local\Temp\ipykernel_51540\967698044.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import WebBaseLoader
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
url = 'https://www.amazon.in/Apple-2026-MacBook-Laptop-chip/dp/B0GR6J183B/ref=sr_1_3?dib=eyJ2IjoiMSJ9.2GeNO-SKFY35P884NewOfZrz0X84Bwd9ijDdnt4Py3CIar64eTtVoSxkGmhlRnvmiJnAMafv1cRIdI2sSLLgqHJEiP_xVYZTo-c90YtuBK6Lfs6ddmA533Wl_2LPCeIjfRsYVbXDBLljPKuqDF1QiyRMGblFpTvYcBATGsF4PE9bxGDPW5qbtqcE--GcilMfM0Tx1PaN1qDjbzYr9G-GxiFuGoul9XyJXr4q6qly5DQ.KAQqS_fx4cJkccHrdWvF97espybqXFboQscPPTy54ys&dib_tag=se&keywords=macbook&qid=1781118320&sr=8-3&th=1'

# %%
loader = WebBaseLoader(url)
data = loader.load()

# %%
data
# Out:
# [Document(metadata={'source': 'https://www.amazon.in/Apple-2026-MacBook-Laptop-chip/dp/B0GR6J183B/ref=sr_1_3?dib=eyJ2IjoiMSJ9.2GeNO-SKFY35P884NewOfZrz0X84Bwd9ijDdnt4Py3CIar64eTtVoSxkGmhlRnvmiJnAMafv1cRIdI2sSLLgqHJEiP_xVYZTo-c90YtuBK6Lfs6ddmA533Wl_2LPCeIjfRsYVbXDBLljPKuqDF1QiyRMGblFpTvYcBATGsF4PE9bxGDPW5qbtqcE--GcilMfM0Tx1PaN1qDjbzYr9G-GxiFuGoul9XyJXr4q6qly5DQ.KAQqS_fx4cJkccHrdWvF97espybqXFboQscPPTy54ys&dib_tag=se&keywords=macbook&qid=1781118320&sr=8-3&th=1', 'title': 'Apple 2026 MacBook Neo 13″ Laptop with A18 Pro chip: Built for AI and Apple Intelligence, Liquid Retina Display, 8GB Unified Memory, 256GB SSD Storage, 1080p FaceTime HD Camera; Silver : Amazon.in: Electronics', 'description': 'Apple 2026 MacBook Neo 13″ Laptop with A18 Pro chip: Built for AI and Apple Intelligence, Liquid Retina Display, 8GB Unified Memory, 256GB SSD Storage, 1080p FaceTime HD Camera; Silver : Amazon.in: Electronics', 'language': 'en-in'}, page_content='\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\
# ...

# %%
content =data[0].page_content.replace('\n', '').replace('About this item', ' ').replace('             ', ' ')

# %%
content
# Out:
# 'Apple 2026 MacBook Neo 13″ Laptop with A18 Pro chip: Built for AI and Apple Intelligence, Liquid Retina Display, 8GB Unified Memory, 256GB SSD Storage, 1080p FaceTime HD Camera; Silver : Amazon.in: ElectronicsSkip to        Main content           Buying options  Compare with similar items  Videos  Reviews            Keyboard shortcuts  Searchalt+/Cartshift+alt+CHomeshift+alt+HOrdersshift+alt+OAdd to cartshift+alt+KProduct summaryshift+alt+DShow/Hide shortcutsshift+alt+ZTo move between items, use your keyboard\'s up or down arrows..in       Delivering to Kanpur 208026           Update location    AllSelect the department you want to search inAll CategoriesAlexa SkillsAmazon DevicesAmazon FashionAmazon FreshAmazon PharmacyAppliancesApps & GamesAudible AudiobooksBabyBeautyBooksCar & MotorbikeClothing & AccessoriesCollectiblesComputers & AccessoriesDealsElectronicsFurnitureGarden & OutdoorsGift CardsGrocery & Gourmet FoodsHealth & Personal CareHome & KitchenIndustrial & ScientificJewell
# ...

# %%
len(content) // 3.5
# Out:
# 12885.0

# %%
data[0].metadata
# Out:
# {'source': 'https://www.amazon.in/Apple-2026-MacBook-Laptop-chip/dp/B0GR6J183B/ref=sr_1_3?dib=eyJ2IjoiMSJ9.2GeNO-SKFY35P884NewOfZrz0X84Bwd9ijDdnt4Py3CIar64eTtVoSxkGmhlRnvmiJnAMafv1cRIdI2sSLLgqHJEiP_xVYZTo-c90YtuBK6Lfs6ddmA533Wl_2LPCeIjfRsYVbXDBLljPKuqDF1QiyRMGblFpTvYcBATGsF4PE9bxGDPW5qbtqcE--GcilMfM0Tx1PaN1qDjbzYr9G-GxiFuGoul9XyJXr4q6qly5DQ.KAQqS_fx4cJkccHrdWvF97espybqXFboQscPPTy54ys&dib_tag=se&keywords=macbook&qid=1781118320&sr=8-3&th=1',
#  'title': 'Apple 2026 MacBook Neo 13″ Laptop with A18 Pro chip: Built for AI and Apple Intelligence, Liquid Retina Display, 8GB Unified Memory, 256GB SSD Storage, 1080p FaceTime HD Camera; Silver : Amazon.in: Electronics',
#  'description': 'Apple 2026 MacBook Neo 13″ Laptop with A18 Pro chip: Built for AI and Apple Intelligence, Liquid Retina Display, 8GB Unified Memory, 256GB SSD Storage, 1080p FaceTime HD Camera; Silver : Amazon.in: Electronics',
#  'language': 'en-in'}
