# %%
sample = """
Artificial intelligence has rapidly evolved from a niche research field into a technology that affects daily life. Modern AI systems can summarize documents, generate images, write code, and assist with customer support. Businesses increasingly rely on machine learning models to automate repetitive tasks and extract insights from large datasets. However, deploying AI at scale introduces challenges such as model monitoring, bias detection, and data privacy compliance.Many students entering the technology industry focus heavily on learning programming languages. While coding skills are important, problem-solving ability often matters more. A developer who understands system design, debugging, and user requirements can usually learn new programming languages quickly. This is why experienced engineers often emphasize projects over passive learning. Building real applications exposes gaps in knowledge that tutorials rarely reveal.
Physical fitness operates on a similar principle. Reading about exercise techniques does not improve strength unless the individual consistently trains. Progressive overload, proper recovery, and balanced nutrition are fundamental factors in long-term athletic development. Small improvements accumulated over months frequently produce better results than short bursts of intense motivation.
The history of space exploration demonstrates humanity's desire to push beyond known boundaries. Early missions focused on reaching orbit and landing on the Moon. Today, attention has shifted toward reusable rockets, commercial spaceflight, and potential missions to Mars. Engineers must solve difficult problems involving fuel efficiency, radiation exposure, and life-support systems before long-duration interplanetary travel becomes practical.
Coffee is one of the most widely consumed beverages in the world. Different brewing methods produce noticeably different flavors. Espresso uses high pressure to extract concentrated coffee, while pour-over techniques emphasize clarity and subtle tasting notes. Factors such as bean origin, roast level, water temperature, and grind size all influence the final cup.
Data analytics plays a crucial role in modern organizations. Analysts collect, clean, and transform raw information before generating reports or dashboards. Decision-makers rely on these insights to optimize marketing campaigns, forecast demand, and identify operational inefficiencies. As data volumes continue to grow, organizations increasingly adopt cloud-based platforms to manage storage and computation.
Although these subjects appear unrelated, they share a common pattern: meaningful progress typically results from iterative improvement. Whether training an AI model, mastering a programming framework, preparing for a marathon, designing spacecraft, brewing coffee, or analyzing business metrics, consistent experimentation and feedback tend to outperform guesswork.
"""

# %%
from langchain_experimental.text_splitter import SemanticChunker
from langchain_google_genai import GoogleGenerativeAIEmbeddings
# Out:
# C:\Users\Aniket\AppData\Local\Temp\ipykernel_3292\3516896284.py:1: DeprecationWarning: `langchain-experimental` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-experimental/issues/87 for details.
#   from langchain_experimental.text_splitter import SemanticChunker

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
text_splitter = SemanticChunker(
    embeddings=GoogleGenerativeAIEmbeddings(
        model="gemini-embedding-2"
    ),
    breakpoint_threshold_type="percentile",
    breakpoint_threshold_amount=70
)

# %%
doc = text_splitter.create_documents([sample])

# %%
doc
# Out:
# [Document(metadata={}, page_content='\nArtificial intelligence has rapidly evolved from a niche research field into a technology that affects daily life. Modern AI systems can summarize documents, generate images, write code, and assist with customer support. Businesses increasingly rely on machine learning models to automate repetitive tasks and extract insights from large datasets. However, deploying AI at scale introduces challenges such as model monitoring, bias detection, and data privacy compliance.Many students entering the technology industry focus heavily on learning programming languages. While coding skills are important, problem-solving ability often matters more.'),
# ...

# %%
for d in doc:
    print(d.page_content)
    print("\n---\n")
# Out:
# Artificial intelligence has rapidly evolved from a niche research field into a technology that affects daily life. Modern AI systems can summarize documents, generate images, write code, and assist with customer support. Businesses increasingly rely on machine learning models to automate repetitive tasks and extract insights from large datasets. However, deploying AI at scale introduces challenges such as model monitoring, bias detection, and data privacy compliance.Many students entering the technology industry focus heavily on learning programming languages. While coding skills are important, problem-solving ability often matters more.
#
# ---
#
# ...
